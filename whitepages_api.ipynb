# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from os import listdir
from os.path import isfile, join
import glob
import requests

# %%
# load csv files collected from fec.gov website
fec_path = 'data/fec-gov'
fec_files = glob.glob(fec_path + "/*.csv")

# create a list of dataframes from the csv files
fec_list_df = []
for x in fec_files:
# set no header and skip first two rows, as we do not use these rows
    df = pd.read_csv(x, header=None, error_bad_lines=False, skiprows=2)
    fec_list_df.append(df)

# concatenate dataframes from fec.gov files into single fec_df
fec_df = pd.concat(fec_list_df, axis=0, ignore_index=True)

# create new dataframe with only the columns we need from fec_df
new_fec_df = fec_df[[0,6,7,8,9,12,13,14,15,16,19,23,24,17,20,21,26]].copy()
new_fec_df = new_fec_df.rename(columns = { 0: "schedule",
                             6: "pac",
                             7: "last_name",
                             8: "first_name",
                             9: "mi",
                             12: "address_1",
                             13: "address_2",
                             14: "city",
                             15: "state",
                             16: "zip_code",
                             19: "contrib_date",
                             23: "employer",
                             24: "occupation",
                             17: "contrib_cycle",
                             20: "contrib_itemize",
                             21: "contrib_agg",
                             26: "conduit"})

# keep only SA11AI (individual contributions) in our new_fec_df dataframe
new_fec_df = new_fec_df.query("schedule == 'SA11AI'")

# remove duplicate rows created by conduit contributions (mostly ActBlue)
new_fec_df = new_fec_df.loc[new_fec_df['conduit'].isnull()]
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,27,28,29,31,32,33,34,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,27,28,29,33,34,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_fec_df
# Out:
#        schedule  pac          last_name first_name       mi  \
# 0        SA11AI  NaN               Cobb      Craig      NaN
# 2        SA11AI  NaN             Thomas       Mike      NaN
# 4        SA11AI  NaN               Ocon      Angel      NaN
# 6        SA11AI  NaN             Weiner     Claire      NaN
# 8        SA11AI  NaN            Gleason      Kevin      NaN
# 10       SA11AI  NaN            Stanley        Len      NaN
# 12       SA11AI  NaN            Kulhavy      David        L
# 14       SA11AI  NaN              White      Merri      NaN
# 16       SA11AI  NaN               Ward      Bruce      NaN
# 18       SA11AI  NaN            Goodwin         K.      NaN
# 20       SA11AI  NaN               West        Ben  Britain
# 21       SA11AI  NaN              Hasan      Saira      NaN
# 23       SA11AI  NaN              Wells   Kathleen      NaN
# 25       SA11AI  NaN             Taylor      Price      NaN
# 27       SA11AI  NaN         Williamson  Stephanie      NaN
# 29       SA11AI  NaN             Spinks       John      NaN
# 31       SA11AI  NaN             Browne      Robby      NaN
# 32       SA11AI  NaN           McDonald      Shawn      NaN
# 34       SA11AI  NaN              Spurr    Charles      NaN
# 36       SA11AI  NaN             Storey       Gail      NaN
# 38       SA11AI  NaN         Thadathill     George      NaN
# 39       SA11AI  NaN              Lowry    Richard      NaN
# 40       SA11AI  NaN          McCulloch    Michael      NaN
# 42       SA11AI  NaN            Martula      David      NaN
# 44       SA11AI  NaN          Goldstein    Richard      NaN
# 46       SA11AI  NaN        Silverstein   Marjorie      NaN
# 48       SA11AI  NaN             Cullen    Michael      NaN
# 50       SA11AI  NaN             Powers    Stephen      NaN
# 52       SA11AI  NaN               Lara       Jose      NaN
# 54       SA11AI  NaN               Leza    Jessica      NaN
# ...         ...  ...                ...        ...      ...
# 358092   SA11AI  NaN             Alongi       John      NaN
# 358093   SA11AI  NaN              Allen         MJ      NaN
# 358095   SA11AI  NaN               Volz      David      NaN
# 358097   SA11AI  NaN            Johnson      Julie      NaN
# 358099   SA11AI  NaN         Villarreal       Jose      NaN
# 358100   SA11AI  NaN            Wehring       Vera      NaN
# 358102   SA11AI  NaN          Feinstein      Jason      NaN
# 358104   SA11AI  NaN              Morse    Melissa      NaN
# 358106   SA11AI  NaN              Smith   Fielding      NaN
# 358108   SA11AI  NaN            Nichols      David      NaN
# 358110   SA11AI  NaN  Bloomfield-Pedley     Robert      NaN
# 358112   SA11AI  NaN       Schoenbucher      Nancy      NaN
# 358114   SA11AI  NaN               Kerr     Roycee      NaN
# 358115   SA11AI  NaN             Loucks       John        S
# 358116   SA11AI  NaN             Howard      Daryl      NaN
# 358118   SA11AI  NaN             Benton      James      NaN
# 358120   SA11AI  NaN               Hair    William      NaN
# 358122   SA11AI  NaN              Keton      James      NaN
# 358124   SA11AI  NaN            Ellison     Gordon      NaN
# 358126   SA11AI  NaN       Fleckenstein      Scott      NaN
# 358128   SA11AI  NaN                Lee      Randy      NaN
# 358130   SA11AI  NaN                Zhu       Ling      NaN
# 358132   SA11AI  NaN       Flores Lopez    Theresa      NaN
# 358134   SA11AI  NaN              Files  Priscilla      NaN
# 358136   SA11AI  NaN           Sullivan    Roxanne      NaN
# 358138   SA11AI  NaN              DeWit       John      NaN
# 358139   SA11AI  NaN            Compton       Alta      NaN
# 358140   SA11AI  NaN            Tremont        Ivo       W.
# 358142   SA11AI  NaN               Bray      Henry      NaN
# 358144   SA11AI  NaN          Mcfarland   Christie      NaN
#
#                      address_1  address_2           city state     zip_code  \
# 0                360 Nueces St   Apt 1513         Austin    TX    787014263
# 2            1400 Stratford Pl        NaN       McKinney    TX    750717481
# 4             2105 Normandy Dr        NaN         Irving    TX    750605617
# 6               1415 Madrid Pl        NaN       Santa Fe    NM    875054641
# 8        240 N Highland Ave NE  Unit 2401        Atlanta    GA    303075622
# 10            1108 N Mangum St        NaN         Durham    NC    277011932
# 12          504 Mockingbird Ln        NaN    Nacogdoches    TX    759646522
# 14             6340 Bridle Trl        NaN    Caddo Mills    TX    751356291
# 16           2237 Pinehurst St        NaN          Tyler    TX    757035809
# 18          3213 Brookshire Dr        NaN          Plano    TX    750754708
# 20            4225 Potomac Ave        NaN         Dallas    TX    752052626
# 21        6216 Monte Cristo Ln        NaN          Plano    TX    750243175
# 23               PO Box 101714        NaN     Fort Worth    TX    761851714
# 25       3207 Harpers Ferry Ln        NaN         Austin    TX    787456722
# 27        117 Canyon Ridge Trl        NaN          Aledo    TX    760083706
# 29      5425 State Highway 7 W        NaN       Crockett    TX    758357848
# 31           25 Central Park W    Apt 21K       New York    NY    100237231
# 32            3210 Carlisle St     Unit 3         Dallas    TX    752041377
# 34             139 Broadway St        NaN      Wakefield    MA    018803105
# 36             5290 Euclid Ave        NaN        Boulder    CO    803032836
# 38        224 Flnnigan Hill DR        NaN         Keller    TX        76248
# 39               56 Cortez Ave        NaN   Rancho Viejo    TX    785759627
# 40                PO Box 61410        NaN        Midland    TX    797111410
# 42              100 Willard St     Apt 13        Houston    TX    770062159
# 44                  PO Box 752        NaN     Sagaponack    NY    119620752
# 46       11811 Legend Manor Dr        NaN        Houston    TX    770823079
# 48             729 Woodland St        NaN        Houston    TX    770097252
# 50                51 Rainey St    Apt 908         Austin    TX    787014510
# 52           17400 Burchit Cir        NaN    Yorba Linda    CA    928865187
# 54           1003 Hillcrest St        NaN         Denton    TX    762012408
# ...                        ...        ...            ...   ...          ...
# 358092      2707 N Lincoln Ave      Apt K        Chicago    IL  6.06142e+08
# 358093            3164 Wood Dr        NaN        Cambria    CA  9.34284e+08
# 358095           108 Tower Blf        NaN         Cibolo    TX  7.81082e+08
# 358097     2105 Town Centre Dr        NaN     Round Rock    TX  7.86648e+08
# 358099         2733 35th St NW   Ste 1500     Washington    DC  2.00071e+08
# 358100            306 N Fm 609        NaN       Flatonia    TX        78941
# 358102      10506 Wagon Gap Dr        NaN         Austin    TX  7.87502e+08
# 358104        1300 Woodhead St        NaN        Houston    TX  7.70195e+08
# 358106      5631 Wickersham Ln        NaN        Houston    TX  7.70564e+08
# 358108           3109 Birch Dr        NaN     Carrollton    TX  7.50073e+08
# 358110       805 Buttonwood Dr        NaN  Winston Salem    NC  2.71041e+08
# 358112       2424 Founders Cir        NaN      Spicewood    TX  7.86693e+08
# 358114         6930 Vivian Ave        NaN         Dallas    TX  7.52231e+08
# 358115           3319 Perry Ln        NaN         Austin    TX  7.87315e+08
# 358116    14100 Nutty Brown Rd        NaN         Austin    TX  7.87379e+08
# 358118          3401 Inwood Cv        NaN     Round Rock    TX  7.86811e+08
# 358120      316 Tree Grove Cir        NaN           Waco    TX  7.67126e+08
# 358122     1727 Lake Breeze Dr        NaN       Rockwall    TX  7.50873e+08
# 358124      22806 Wichita Pass        NaN    San Antonio    TX  7.82583e+08
# 358126        1317 W French Pl      Apt 2    San Antonio    TX  7.82016e+08
# 358128      500 E Riverside Dr    Apt 251         Austin    TX  7.87041e+08
# 358130           2615 Dante Ct        NaN         Austin    TX  7.87483e+08
# 358132              407 Ken Dr        NaN    San Antonio    TX  7.82583e+08
# 358134         4823 Houston Dr        NaN      Galveston    TX  7.75515e+08
# 358136        12431 Highway 82        NaN     Carbondale    CO   8.1624e+08
# 358138       101 E McKinney St  Unit 1982         Denton    TX  7.62024e+08
# 358139   3611 Trailway Park St        NaN    San Antonio    TX  7.82473e+08
# 358140            6445 Main St      Fl 24        Houston    TX  7.70302e+08
# 358142          10 Dashwood Ct        NaN      The Hills    TX  7.87381e+08
# 358144   8547 San Fernando Way        NaN         Dallas    TX  7.52184e+08
#
#         contrib_date                            employer  \
# 0           20180709                         Allclear ID
# 2           20180709                       Self Employed
# 4           20180709         Electrical Surplus Of Texas
# 6           20180709                        Not Employed
# 8           20180719                       Tanner Health
# 10          20180719                        Not Employed
# 12          20180719  Stephen F. Austin State University
# 14          20180730                         Beacon Hill
# 16          20180730                        Not Employed
# 18          20180730           The Quatrefoil Group Inc.
# 20          20180730               Thompson & Knight LLP
# 21          20180820                       Amity Hospice
# 23          20180830                       Self Employed
# 25          20180830                     Delta Millworks
# 27          20180830                        Not Employed
# 29          20180830                        Not Employed
# 31          20180910                  The Corcoran Group
# 32          20180910                       Self Employed
# 34          20180910                           Kayak.com
# 36          20180910                       Self Employed
# 38          20180910           Fort Worth Public Library
# 39          20180910                        Not Employed
# 40          20180920                       Self Employed
# 42          20180920                   Shell Oil Company
# 44          20180920                        Not Employed
# 46          20180928                       Self Employed
# 48          20180928                      Rainbow Ninjas
# 50          20180928       Endurance International Group
# 52          20180928                               SFFCU
# 54          20180928     Music Therapy Services Of Texas
# ...              ...                                 ...
# 358092      20180428             Northwestern University
# 358093      20180617                       Self Employed
# 358095      20180615                        Not Employed
# 358097      20180616                        Not Employed
# 358099      20180628                       Self Employed
# 358100      20180627                        Not Employed
# 358102      20180403                     Edison Labs Inc
# 358104      20180403                        Not Employed
# 358106      20180408                        Not Employed
# 358108      20180404                              CFBISD
# 358110      20180404                       Self Employed
# 358112      20180403                        Not Employed
# 358114      20180409                     Talent 2.0, LLC
# 358115      20180519             St. Edward's University
# 358116      20180527                       Self Employed
# 358118      20180527                        Not Employed
# 358120      20180527                   Baylor University
# 358122      20180527                       Palladin Inc.
# 358124      20180527                        Not Employed
# 358126      20180527      Stellar Development Foundation
# 358128      20180527                        Not Employed
# 358130      20180527                                 IBM
# 358132      20180527                        Not Employed
# 358134      20180618   Galveston Island Tree Conservancy
# 358136      20180618                        Not Employed
# 358138      20180609                        Not Employed
# 358139      20180629                  Trinity University
# 358140      20180628                        Not Employed
# 358142      20180628                        Not Employed
# 358144      20180628                        Not Employed
#
#                              occupation contrib_cycle  contrib_itemize  \
# 0              Senior Software Engineer         G2018            100.0
# 2                              Attorney         G2018            200.0
# 4       Electrical Equipment Technician         G2018             63.0
# 6                          Not Employed         G2018             50.0
# 8                             Physician         G2018             50.0
# 10                         Not Employed         G2018             25.0
# 12                             Educator         G2018             25.0
# 14                           Accountant         G2018            100.0
# 16                         Not Employed         G2018            250.0
# 18                                  CEO         G2018            100.0
# 20                             Attorney         G2018            100.0
# 21                                Owner         G2018            100.0
# 23                             Attorney         G2018            100.0
# 25                       Vice President         G2018            100.0
# 27                         Not Employed         G2018             25.0
# 29                              Retired         G2018             25.0
# 31                              Realtor         G2018           1000.0
# 32                             Attorney         G2018            150.0
# 34                    Software Engineer         G2018            100.0
# 36                               Writer         G2018            100.0
# 38                     Senior Librarian         G2018            250.0
# 39                              Retired         G2018            500.0
# 40                         Veterinarian         G2018            500.0
# 42                             Engineer         G2018             40.0
# 44                         Not Employed         G2018             12.5
# 46                               Artist         G2018             25.0
# 48                      General Manager         G2018             25.0
# 50             Senior Systems Architect         G2018             50.0
# 52                              Banking         G2018            100.0
# 54                      Music Therapist         G2018             25.0
# ...                                 ...           ...              ...
# 358092                        Professor         G2018            500.0
# 358093                       Accountant         G2018             50.0
# 358095                     Not Employed         G2018             25.0
# 358097                     Not Employed         G2018             20.0
# 358099                         Attorney         G2018           2000.0
# 358100                     Not Employed         G2018             25.0
# 358102                Software Engineer         G2018            100.0
# 358104                          Retired         G2018            100.0
# 358106                     Not Employed         G2018            100.0
# 358108                          Teacher         G2018             25.0
# 358110                Healthcare Worker         G2018             25.0
# 358112                     Not Employed         G2018              5.0
# 358114       Human Resources Consultant         G2018             35.5
# 358115                        Professor         G2018             35.5
# 358116                           Artist         G2018            250.0
# 358118                     Not Employed         G2018            100.0
# 358120                        Librarian         G2018            100.0
# 358122                              CFO         G2018            100.0
# 358124                     Not Employed         G2018             25.0
# 358126                Software Engineer         G2018             25.0
# 358128                     Not Employed         G2018             25.0
# 358130              Business Consultant         G2018             25.0
# 358132                     Not Employed         G2018              5.0
# 358134                         Arborist         G2018             50.0
# 358136                     Not Employed         G2018            250.0
# 358138                          Retired         G2018            100.0
# 358139          Donor Relations Officer         G2018            100.0
# 358140                     Not Employed         G2018            250.0
# 358142                          Retired         G2018           1000.0
# 358144                     Not Employed         G2018             10.0
#
#         contrib_agg conduit
# 0            925.00     NaN
# 2            500.00     NaN
# 4            176.00     NaN
# 6            525.00     NaN
# 8            200.00     NaN
# 10           262.50     NaN
# 12           790.00     NaN
# 14           420.75     NaN
# 16           525.00     NaN
# 18           300.00     NaN
# 20           450.00     NaN
# 21           100.00     NaN
# 23          1032.74     NaN
# 25           357.88     NaN
# 27           175.00     NaN
# 29           177.73     NaN
# 31          1000.00     NaN
# 32           250.00     NaN
# 34          2450.00     NaN
# 36           400.00     NaN
# 38           250.00     NaN
# 39           500.00     NaN
# 40          2000.00     NaN
# 42           657.00     NaN
# 44          1363.33     NaN
# 46           675.00     NaN
# 48           358.00     NaN
# 50          3607.00     NaN
# 52           526.00     NaN
# 54           253.23     NaN
# ...             ...     ...
# 358092       500.00     NaN
# 358093       275.00     NaN
# 358095       275.00     NaN
# 358097       370.00     NaN
# 358099      2000.00     NaN
# 358100       310.00     NaN
# 358102       228.94     NaN
# 358104       220.00     NaN
# 358106       432.50     NaN
# 358108       375.00     NaN
# 358110       375.00     NaN
# 358112       224.14     NaN
# 358114       335.50     NaN
# 358115       335.50     NaN
# 358116       250.00     NaN
# 358118       508.75     NaN
# 358120       325.00     NaN
# 358122       250.00     NaN
# 358124       553.00     NaN
# 358126       350.00     NaN
# 358128       503.74     NaN
# 358130       500.00     NaN
# 358132       230.00     NaN
# 358134       620.50     NaN
# 358136       250.00     NaN
# 358138       436.14     NaN
# 358139       590.62     NaN
# 358140       250.00     NaN
# 358142      1000.00     NaN
# 358144       250.00     NaN
#
# [184783 rows x 17 columns]

# %%
# pull out 100 records to test with Whitepages API
sample_df = new_fec_df.iloc[0:2]

sample_df
# Out:
#   schedule  pac last_name first_name   mi          address_1 address_2  \
# 0   SA11AI  NaN      Cobb      Craig  NaN      360 Nueces St  Apt 1513
# 2   SA11AI  NaN    Thomas       Mike  NaN  1400 Stratford Pl       NaN
#
#        city state   zip_code  contrib_date       employer  \
# 0    Austin    TX  787014263      20180709    Allclear ID
# 2  McKinney    TX  750717481      20180709  Self Employed
#
#                  occupation contrib_cycle  contrib_itemize  contrib_agg  \
# 0  Senior Software Engineer         G2018            100.0        925.0
# 2                  Attorney         G2018            200.0        500.0
#
#   conduit
# 0     NaN
# 2     NaN

# %%
# limit columns to just what is needed for the API call 
sample_df = sample_df.iloc[:,5:10]
sample_df
# Out:
#            address_1 address_2      city state   zip_code
# 0      360 Nueces St  Apt 1513    Austin    TX  787014263
# 2  1400 Stratford Pl       NaN  McKinney    TX  750717481

# %%
sample_df['zip_5'] = sample_df['zip_code'].astype(str).str[:5]
sample_df
# Out:
#            address_1 address_2      city state   zip_code  zip_5
# 0      360 Nueces St  Apt 1513    Austin    TX  787014263  78701
# 2  1400 Stratford Pl       NaN  McKinney    TX  750717481  75071

# %%
# replace spaces with '+' for whitepages API format
formatted_sample_df = sample_df.replace({' ': '+'}, regex=True)
formatted_sample_df
# Out:
#            address_1 address_2      city state   zip_code  zip_5
# 0      360+Nueces+St  Apt+1513    Austin    TX  787014263  78701
# 2  1400+Stratford+Pl       NaN  McKinney    TX  750717481  75071

# %%
# concatenate address columns into one list of addresses
formatted_sample_df['addresses'] = 'street_line_1=' + formatted_sample_df['address_1'].astype(str) \
                                    + '&city=' + formatted_sample_df['city'].astype(str) \
                                    + '&postal_code=' + formatted_sample_df['zip_5'].astype(str) \
                                    + '&state_code=' + formatted_sample_df['state'].astype(str) \
                                    + '&api_key=[api-key]'

formatted_sample_df
# Out:
#            address_1 address_2      city state   zip_code  zip_5  \
# 0      360+Nueces+St  Apt+1513    Austin    TX  787014263  78701
# 2  1400+Stratford+Pl       NaN  McKinney    TX  750717481  75071
#
#                                            addresses
# 0  street_line_1=360+Nueces+St&city=Austin&postal...
# 2  street_line_1=1400+Stratford+Pl&city=McKinney&...

# %%
addresses = formatted_sample_df['addresses'].tolist()
addresses
# Out:
# ['street_line_1=360+Nueces+St&city=Austin&postal_code=78701&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7',
#  'street_line_1=1400+Stratford+Pl&city=McKinney&postal_code=75071&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7']

# %%
# Starting URL for Whitepages API Call
url = "https://proapi.whitepages.com/3.0/location?" 

# List of donor address data


# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, address in enumerate(addresses):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    address_url = url + address
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, address))

    # Add 1 to the record count
    record_count += 1

    print(address_url)
        
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        address_search = requests.get(address_url).json()
        print(type(address_search))
        phone = address_search['current_residents'][0]['phones'][0]['phone_number']
        address_data ={
            "Phone": phone
            }

    # If an error is experienced, skip the city
    except:
        print("Address not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | street_line_1=360+Nueces+St&city=Austin&postal_code=78701&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7
# https://proapi.whitepages.com/3.0/location?street_line_1=360+Nueces+St&city=Austin&postal_code=78701&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7
# <class 'dict'>
# 21
# Address not found. Skipping...
# Processing Record 2 of Set 1 | street_line_1=1400+Stratford+Pl&city=McKinney&postal_code=75071&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7
# https://proapi.whitepages.com/3.0/location?street_line_1=1400+Stratford+Pl&city=McKinney&postal_code=75071&state_code=TX&api_key=798a9277ff2440b1863f73adc5dbf7b7
# <class 'dict'>
# 21
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
address_data
# Out:
# {'Phone': '+18067959992'}

# %%
address_search
# Out:
# {'id': 'Location.0b95540e-e70d-4666-b61a-dbcb91c0eeab',
#  'is_valid': True,
#  'street_line_1': '1400 Stratford Pl',
#  'street_line_2': None,
#  'city': 'McKinney',
#  'postal_code': '75071',
#  'zip4': '7481',
#  'state_code': 'TX',
#  'country_code': 'US',
#  'lat_long': {'latitude': 33.213913,
#   'longitude': -96.72142,
#   'accuracy': 'RoofTop'},
#  'is_active': True,
#  'is_commercial': False,
#  'is_forwarder': False,
#  'delivery_point': 'SingleUnit',
#  'current_residents': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#    'name': 'Laurel Owens Burnette',
#    'firstname': 'Laurel',
#    'middlename': 'Owens',
#    'lastname': 'Burnette',
#    'alternate_names': [],
#    'age_range': '85-89',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2017-11-01',
#    'phones': [{'id': 'Phone.99716fef-a2e1-4b08-cfe3-bc7128b7c1c6',
#      'phone_number': '+18067959992',
#      'line_type': 'Landline'}],
#    'historical_addresses': [{'id': 'Location.70874516-c179-4226-8329-2461fae1e222',
#      'location_type': 'Address',
#      'street_line_1': '1717 Norfolk Ave Apt 2419',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79416',
#      'zip4': '6036',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.5809364318848,
#       'longitude': -101.89875793457,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '2014-06-01',
#      'link_to_person_end_date': '2017-11-01'},
#     {'id': 'Location.bf7379ee-b441-4b8e-b79f-8ebe2752eebc',
#      'location_type': 'Address',
#      'street_line_1': '3007 59th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '5511',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.540199,
#       'longitude': -101.88002,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1987-03-01',
#      'link_to_person_end_date': '2014-06-01'}],
#    'associated_people': [{'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#      'name': 'Mr. Mike Allen Thomas',
#      'firstname': 'Mike',
#      'middlename': 'Allen',
#      'lastname': 'Thomas',
#      'relation': 'ParentInLaw_ChildInLaw'},
#     {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#      'name': 'Shelley Burnette Thomas',
#      'firstname': 'Shelley',
#      'middlename': 'Burnette',
#      'lastname': 'Thomas',
#      'relation': 'Parent_Child'}]},
#   {'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#    'name': 'Mr. Mike Allen Thomas',
#    'firstname': 'Mike',
#    'middlename': 'Allen',
#    'lastname': 'Thomas',
#    'alternate_names': [],
#    'age_range': '70-74',
#    'gender': 'Male',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2004-12-01',
#    'phones': [{'id': 'Phone.b9dd6fef-a2df-4b08-cfe3-bc7128b6ffb5',
#      'phone_number': '+12145049838',
#      'line_type': 'FixedVOIP'}],
#    'historical_addresses': [{'id': 'Location.cf54ef7d-91b9-4f9e-bda7-bb6e570fedf7',
#      'location_type': 'Address',
#      'street_line_1': '4270 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': None,
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513375,
#       'longitude': -101.90358,
#       'accuracy': 'RoofTop'},
#      'is_active': None,
#      'delivery_point': None,
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1990-01-01'},
#     {'id': 'Location.787b2640-45ad-4eb2-84a2-654627160f64',
#      'location_type': 'Address',
#      'street_line_1': '1213 Moselle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1115',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.1867294311523,
#       'longitude': -115.332588195801,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2000-07-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.e3ed5133-eaae-4c2e-aeba-4bcb1064524b',
#      'location_type': 'Address',
#      'street_line_1': '4205 49th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '3721',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.549652,
#       'longitude': -101.901352,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1992-05-01'},
#     {'id': 'Location.71ce834a-950f-48f5-9405-9af201ba3f50',
#      'location_type': 'Address',
#      'street_line_1': '9702 York Pl',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4871',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.506145,
#       'longitude': -101.921257,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1986-10-01',
#      'link_to_person_end_date': '2000-08-01'},
#     {'id': 'Location.0a46ed18-3db9-44fc-9632-8c818ae032f0',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 65150',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79464',
#      'zip4': '5150',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 34.724258,
#       'longitude': -98.426922,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'POBox',
#      'link_to_person_start_date': '1997-09-01',
#      'link_to_person_end_date': '2001-03-01'},
#     {'id': 'Location.de3985b7-7ead-4303-a393-951ebaca2787',
#      'location_type': 'Address',
#      'street_line_1': '4210 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': '2941',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513733,
#       'longitude': -101.903374,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1985-11-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.fea2ac59-978d-4ef2-b84b-45e0ce4a5c7c',
#      'location_type': 'Address',
#      'street_line_1': '5703 86th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4613',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.515396,
#       'longitude': -101.937088,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1998-01-01',
#      'link_to_person_end_date': '1999-01-01'},
#     {'id': 'Location.9cd58a13-1dc9-4f31-a29c-c10e4b5a6ea9',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 10113',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79408',
#      'zip4': '3113',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.455109,
#       'longitude': -102.01225,
#       'accuracy': 'RoofTop'},
#      'is_active': None,
#      'delivery_point': None,
#      'link_to_person_start_date': '1990-01-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.7be3741b-3670-42b6-98f5-84705e273211',
#      'location_type': 'Address',
#      'street_line_1': '1408 Chambolle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1136',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.187672,
#       'longitude': -115.331993,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2001-01-01',
#      'link_to_person_end_date': '2009-04-30'}],
#    'associated_people': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#      'name': 'Laurel Owens Burnette',
#      'firstname': 'Laurel',
#      'middlename': 'Owens',
#      'lastname': 'Burnette',
#      'relation': 'ParentInLaw_ChildInLaw'},
#     {'id': 'Person.2bf1c3b8-afbc-4c0d-9ba3-e41ac750256d',
#      'name': 'Tracie G Grimshaw',
#      'firstname': 'Tracie',
#      'middlename': 'G',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'},
#     {'id': 'Person.ee2468c1-cea8-4416-85d5-7a523266ccdf',
#      'name': 'Richard L Nye',
#      'firstname': 'Richard',
#      'middlename': 'L',
#      'lastname': 'Nye',
#      'relation': 'SiblingInLaw'},
#     {'id': 'Person.30589a87-c512-4245-811a-6b61d3c55459',
#      'name': 'Shelby Edith Proud',
#      'firstname': 'Shelby',
#      'middlename': 'Edith',
#      'lastname': 'Proud',
#      'relation': 'Relative'},
#     {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#      'name': 'Shelley Burnette Thomas',
#      'firstname': 'Shelley',
#      'middlename': 'Burnette',
#      'lastname': 'Thomas',
#      'relation': 'Spouse'}]},
#   {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#    'name': 'Shelley Burnette Thomas',
#    'firstname': 'Shelley',
#    'middlename': 'Burnette',
#    'lastname': 'Thomas',
#    'alternate_names': ['Shelley Burnette Burnette'],
#    'age_range': '55-59',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2004-12-01',
#    'phones': [{'id': 'Phone.b9dd6fef-a2df-4b08-cfe3-bc7128b6ffb5',
#      'phone_number': '+12145049838',
#      'line_type': 'FixedVOIP'}],
#    'historical_addresses': [{'id': 'Location.787b2640-45ad-4eb2-84a2-654627160f64',
#      'location_type': 'Address',
#      'street_line_1': '1213 Moselle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1115',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.1867294311523,
#       'longitude': -115.332588195801,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2000-07-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.71ce834a-950f-48f5-9405-9af201ba3f50',
#      'location_type': 'Address',
#      'street_line_1': '9702 York Pl',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4871',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.506145,
#       'longitude': -101.921257,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1998-06-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.0a46ed18-3db9-44fc-9632-8c818ae032f0',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 65150',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79464',
#      'zip4': '5150',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 34.724258,
#       'longitude': -98.426922,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'POBox',
#      'link_to_person_start_date': '1989-09-01',
#      'link_to_person_end_date': '1998-06-01'},
#     {'id': 'Location.de3985b7-7ead-4303-a393-951ebaca2787',
#      'location_type': 'Address',
#      'street_line_1': '4210 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': '2941',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513733,
#       'longitude': -101.903374,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.d4456c4d-e5b2-4147-8a5a-fbd22a9a3a31',
#      'location_type': 'Address',
#      'street_line_1': '5402 66th St Apt 1227',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '1345',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.5352096557617,
#       'longitude': -101.931205749512,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '1986-04-01',
#      'link_to_person_end_date': '1998-08-01'},
#     {'id': 'Location.15818670-72a5-4d6d-9a4b-328932264481',
#      'location_type': 'Address',
#      'street_line_1': '7305 Aberdeen Ave Apt 2703',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '2550',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.527279,
#       'longitude': -101.92506,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '1991-12-01',
#      'link_to_person_end_date': '1992-01-01'},
#     {'id': 'Location.fea2ac59-978d-4ef2-b84b-45e0ce4a5c7c',
#      'location_type': 'Address',
#      'street_line_1': '5703 86th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4613',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.515396,
#       'longitude': -101.937088,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1997-10-01',
#      'link_to_person_end_date': '1999-01-01'},
#     {'id': 'Location.bf7379ee-b441-4b8e-b79f-8ebe2752eebc',
#      'location_type': 'Address',
#      'street_line_1': '3007 59th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '5511',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.540199,
#       'longitude': -101.88002,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1990-04-01'},
#     {'id': 'Location.7be3741b-3670-42b6-98f5-84705e273211',
#      'location_type': 'Address',
#      'street_line_1': '1408 Chambolle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1136',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.187672,
#       'longitude': -115.331993,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2001-01-01',
#      'link_to_person_end_date': '2005-04-01'}],
#    'associated_people': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#      'name': 'Laurel Owens Burnette',
#      'firstname': 'Laurel',
#      'middlename': 'Owens',
#      'lastname': 'Burnette',
#      'relation': 'Parent_Child'},
#     {'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#      'name': 'Mr. Mike Allen Thomas',
#      'firstname': 'Mike',
#      'middlename': 'Allen',
#      'lastname': 'Thomas',
#      'relation': 'Spouse'},
#     {'id': 'Person.2bf1c3b8-afbc-4c0d-9ba3-e41ac750256d',
#      'name': 'Tracie G Grimshaw',
#      'firstname': 'Tracie',
#      'middlename': 'G',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'},
#     {'id': 'Person.88671b5f-3cbb-4134-aee0-568ef4642f05',
#      'name': 'Carolyn J Johnsen',
#      'firstname': 'Carolyn',
#      'middlename': 'J',
#      'lastname': 'Johnsen',
#      'relation': 'SiblingInLaw'},
#     {'id': 'Person.41981673-3dee-4777-bcdd-3ddd27508e20',
#      'name': 'John Clark Grimshaw',
#      'firstname': 'John',
#      'middlename': 'Clark',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'}]},
#   {'id': 'Person.e71dd2d1-5d15-46b9-8f4b-f3936f80faed',
#    'name': 'Laurel J Burnette',
#    'firstname': 'Laurel',
#    'middlename': 'J',
#    'lastname': 'Burnette',
#    'alternate_names': [],
#    'age_range': '85-89',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2018-06-11',
#    'phones': [],
#    'historical_addresses': [],
#    'associated_people': []}],
#  'last_sale_date': '2004-12-14',
#  'total_value': 585739,
#  'owners': [{'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#    'name': 'Mr. Mike Allen Thomas',
#    'firstname': 'Mike',
#    'middlename': 'Allen',
#    'lastname': 'Thomas',
#    'alternate_names': [],
#    'age_range': '70-74',
#    'gender': 'Male',
#    'type': 'Person'}],
#  'associated_addresses': [],
#  'error': None,
#  'warnings': []}

# %%
import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
flatten_dict = flatten(address_search)

# %%
flatten_dict
# Out:
# {'id': 'Location.0b95540e-e70d-4666-b61a-dbcb91c0eeab',
#  'is_valid': True,
#  'street_line_1': '1400 Stratford Pl',
#  'street_line_2': None,
#  'city': 'McKinney',
#  'postal_code': '75071',
#  'zip4': '7481',
#  'state_code': 'TX',
#  'country_code': 'US',
#  'lat_long_latitude': 33.213913,
#  'lat_long_longitude': -96.72142,
#  'lat_long_accuracy': 'RoofTop',
#  'is_active': True,
#  'is_commercial': False,
#  'is_forwarder': False,
#  'delivery_point': 'SingleUnit',
#  'current_residents': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#    'name': 'Laurel Owens Burnette',
#    'firstname': 'Laurel',
#    'middlename': 'Owens',
#    'lastname': 'Burnette',
#    'alternate_names': [],
#    'age_range': '85-89',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2017-11-01',
#    'phones': [{'id': 'Phone.99716fef-a2e1-4b08-cfe3-bc7128b7c1c6',
#      'phone_number': '+18067959992',
#      'line_type': 'Landline'}],
#    'historical_addresses': [{'id': 'Location.70874516-c179-4226-8329-2461fae1e222',
#      'location_type': 'Address',
#      'street_line_1': '1717 Norfolk Ave Apt 2419',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79416',
#      'zip4': '6036',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.5809364318848,
#       'longitude': -101.89875793457,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '2014-06-01',
#      'link_to_person_end_date': '2017-11-01'},
#     {'id': 'Location.bf7379ee-b441-4b8e-b79f-8ebe2752eebc',
#      'location_type': 'Address',
#      'street_line_1': '3007 59th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '5511',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.540199,
#       'longitude': -101.88002,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1987-03-01',
#      'link_to_person_end_date': '2014-06-01'}],
#    'associated_people': [{'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#      'name': 'Mr. Mike Allen Thomas',
#      'firstname': 'Mike',
#      'middlename': 'Allen',
#      'lastname': 'Thomas',
#      'relation': 'ParentInLaw_ChildInLaw'},
#     {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#      'name': 'Shelley Burnette Thomas',
#      'firstname': 'Shelley',
#      'middlename': 'Burnette',
#      'lastname': 'Thomas',
#      'relation': 'Parent_Child'}]},
#   {'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#    'name': 'Mr. Mike Allen Thomas',
#    'firstname': 'Mike',
#    'middlename': 'Allen',
#    'lastname': 'Thomas',
#    'alternate_names': [],
#    'age_range': '70-74',
#    'gender': 'Male',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2004-12-01',
#    'phones': [{'id': 'Phone.b9dd6fef-a2df-4b08-cfe3-bc7128b6ffb5',
#      'phone_number': '+12145049838',
#      'line_type': 'FixedVOIP'}],
#    'historical_addresses': [{'id': 'Location.cf54ef7d-91b9-4f9e-bda7-bb6e570fedf7',
#      'location_type': 'Address',
#      'street_line_1': '4270 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': None,
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513375,
#       'longitude': -101.90358,
#       'accuracy': 'RoofTop'},
#      'is_active': None,
#      'delivery_point': None,
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1990-01-01'},
#     {'id': 'Location.787b2640-45ad-4eb2-84a2-654627160f64',
#      'location_type': 'Address',
#      'street_line_1': '1213 Moselle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1115',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.1867294311523,
#       'longitude': -115.332588195801,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2000-07-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.e3ed5133-eaae-4c2e-aeba-4bcb1064524b',
#      'location_type': 'Address',
#      'street_line_1': '4205 49th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '3721',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.549652,
#       'longitude': -101.901352,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1992-05-01'},
#     {'id': 'Location.71ce834a-950f-48f5-9405-9af201ba3f50',
#      'location_type': 'Address',
#      'street_line_1': '9702 York Pl',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4871',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.506145,
#       'longitude': -101.921257,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1986-10-01',
#      'link_to_person_end_date': '2000-08-01'},
#     {'id': 'Location.0a46ed18-3db9-44fc-9632-8c818ae032f0',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 65150',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79464',
#      'zip4': '5150',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 34.724258,
#       'longitude': -98.426922,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'POBox',
#      'link_to_person_start_date': '1997-09-01',
#      'link_to_person_end_date': '2001-03-01'},
#     {'id': 'Location.de3985b7-7ead-4303-a393-951ebaca2787',
#      'location_type': 'Address',
#      'street_line_1': '4210 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': '2941',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513733,
#       'longitude': -101.903374,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1985-11-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.fea2ac59-978d-4ef2-b84b-45e0ce4a5c7c',
#      'location_type': 'Address',
#      'street_line_1': '5703 86th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4613',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.515396,
#       'longitude': -101.937088,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1998-01-01',
#      'link_to_person_end_date': '1999-01-01'},
#     {'id': 'Location.9cd58a13-1dc9-4f31-a29c-c10e4b5a6ea9',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 10113',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79408',
#      'zip4': '3113',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.455109,
#       'longitude': -102.01225,
#       'accuracy': 'RoofTop'},
#      'is_active': None,
#      'delivery_point': None,
#      'link_to_person_start_date': '1990-01-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.7be3741b-3670-42b6-98f5-84705e273211',
#      'location_type': 'Address',
#      'street_line_1': '1408 Chambolle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1136',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.187672,
#       'longitude': -115.331993,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2001-01-01',
#      'link_to_person_end_date': '2009-04-30'}],
#    'associated_people': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#      'name': 'Laurel Owens Burnette',
#      'firstname': 'Laurel',
#      'middlename': 'Owens',
#      'lastname': 'Burnette',
#      'relation': 'ParentInLaw_ChildInLaw'},
#     {'id': 'Person.2bf1c3b8-afbc-4c0d-9ba3-e41ac750256d',
#      'name': 'Tracie G Grimshaw',
#      'firstname': 'Tracie',
#      'middlename': 'G',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'},
#     {'id': 'Person.ee2468c1-cea8-4416-85d5-7a523266ccdf',
#      'name': 'Richard L Nye',
#      'firstname': 'Richard',
#      'middlename': 'L',
#      'lastname': 'Nye',
#      'relation': 'SiblingInLaw'},
#     {'id': 'Person.30589a87-c512-4245-811a-6b61d3c55459',
#      'name': 'Shelby Edith Proud',
#      'firstname': 'Shelby',
#      'middlename': 'Edith',
#      'lastname': 'Proud',
#      'relation': 'Relative'},
#     {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#      'name': 'Shelley Burnette Thomas',
#      'firstname': 'Shelley',
#      'middlename': 'Burnette',
#      'lastname': 'Thomas',
#      'relation': 'Spouse'}]},
#   {'id': 'Person.e600a92f-dfb1-4919-afd8-0bb0550dd9ad',
#    'name': 'Shelley Burnette Thomas',
#    'firstname': 'Shelley',
#    'middlename': 'Burnette',
#    'lastname': 'Thomas',
#    'alternate_names': ['Shelley Burnette Burnette'],
#    'age_range': '55-59',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2004-12-01',
#    'phones': [{'id': 'Phone.b9dd6fef-a2df-4b08-cfe3-bc7128b6ffb5',
#      'phone_number': '+12145049838',
#      'line_type': 'FixedVOIP'}],
#    'historical_addresses': [{'id': 'Location.787b2640-45ad-4eb2-84a2-654627160f64',
#      'location_type': 'Address',
#      'street_line_1': '1213 Moselle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1115',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.1867294311523,
#       'longitude': -115.332588195801,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2000-07-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.71ce834a-950f-48f5-9405-9af201ba3f50',
#      'location_type': 'Address',
#      'street_line_1': '9702 York Pl',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4871',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.506145,
#       'longitude': -101.921257,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1998-06-01',
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.0a46ed18-3db9-44fc-9632-8c818ae032f0',
#      'location_type': 'Address',
#      'street_line_1': 'PO Box 65150',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79464',
#      'zip4': '5150',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 34.724258,
#       'longitude': -98.426922,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'POBox',
#      'link_to_person_start_date': '1989-09-01',
#      'link_to_person_end_date': '1998-06-01'},
#     {'id': 'Location.de3985b7-7ead-4303-a393-951ebaca2787',
#      'location_type': 'Address',
#      'street_line_1': '4210 88th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79423',
#      'zip4': '2941',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.513733,
#       'longitude': -101.903374,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '2003-01-01'},
#     {'id': 'Location.d4456c4d-e5b2-4147-8a5a-fbd22a9a3a31',
#      'location_type': 'Address',
#      'street_line_1': '5402 66th St Apt 1227',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '1345',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.5352096557617,
#       'longitude': -101.931205749512,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '1986-04-01',
#      'link_to_person_end_date': '1998-08-01'},
#     {'id': 'Location.15818670-72a5-4d6d-9a4b-328932264481',
#      'location_type': 'Address',
#      'street_line_1': '7305 Aberdeen Ave Apt 2703',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '2550',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.527279,
#       'longitude': -101.92506,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'MultiUnit',
#      'link_to_person_start_date': '1991-12-01',
#      'link_to_person_end_date': '1992-01-01'},
#     {'id': 'Location.fea2ac59-978d-4ef2-b84b-45e0ce4a5c7c',
#      'location_type': 'Address',
#      'street_line_1': '5703 86th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79424',
#      'zip4': '4613',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.515396,
#       'longitude': -101.937088,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '1997-10-01',
#      'link_to_person_end_date': '1999-01-01'},
#     {'id': 'Location.bf7379ee-b441-4b8e-b79f-8ebe2752eebc',
#      'location_type': 'Address',
#      'street_line_1': '3007 59th St',
#      'street_line_2': None,
#      'city': 'Lubbock',
#      'postal_code': '79413',
#      'zip4': '5511',
#      'state_code': 'TX',
#      'country_code': 'US',
#      'lat_long': {'latitude': 33.540199,
#       'longitude': -101.88002,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': None,
#      'link_to_person_end_date': '1990-04-01'},
#     {'id': 'Location.7be3741b-3670-42b6-98f5-84705e273211',
#      'location_type': 'Address',
#      'street_line_1': '1408 Chambolle Ct',
#      'street_line_2': None,
#      'city': 'Las Vegas',
#      'postal_code': '89144',
#      'zip4': '1136',
#      'state_code': 'NV',
#      'country_code': 'US',
#      'lat_long': {'latitude': 36.187672,
#       'longitude': -115.331993,
#       'accuracy': 'RoofTop'},
#      'is_active': True,
#      'delivery_point': 'SingleUnit',
#      'link_to_person_start_date': '2001-01-01',
#      'link_to_person_end_date': '2005-04-01'}],
#    'associated_people': [{'id': 'Person.a9bb57a2-8c1f-4017-b6db-1a6b13c054ad',
#      'name': 'Laurel Owens Burnette',
#      'firstname': 'Laurel',
#      'middlename': 'Owens',
#      'lastname': 'Burnette',
#      'relation': 'Parent_Child'},
#     {'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#      'name': 'Mr. Mike Allen Thomas',
#      'firstname': 'Mike',
#      'middlename': 'Allen',
#      'lastname': 'Thomas',
#      'relation': 'Spouse'},
#     {'id': 'Person.2bf1c3b8-afbc-4c0d-9ba3-e41ac750256d',
#      'name': 'Tracie G Grimshaw',
#      'firstname': 'Tracie',
#      'middlename': 'G',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'},
#     {'id': 'Person.88671b5f-3cbb-4134-aee0-568ef4642f05',
#      'name': 'Carolyn J Johnsen',
#      'firstname': 'Carolyn',
#      'middlename': 'J',
#      'lastname': 'Johnsen',
#      'relation': 'SiblingInLaw'},
#     {'id': 'Person.41981673-3dee-4777-bcdd-3ddd27508e20',
#      'name': 'John Clark Grimshaw',
#      'firstname': 'John',
#      'middlename': 'Clark',
#      'lastname': 'Grimshaw',
#      'relation': 'Relative'}]},
#   {'id': 'Person.e71dd2d1-5d15-46b9-8f4b-f3936f80faed',
#    'name': 'Laurel J Burnette',
#    'firstname': 'Laurel',
#    'middlename': 'J',
#    'lastname': 'Burnette',
#    'alternate_names': [],
#    'age_range': '85-89',
#    'gender': 'Female',
#    'type': 'Person',
#    'industry': None,
#    'link_to_address_start_date': '2018-06-11',
#    'phones': [],
#    'historical_addresses': [],
#    'associated_people': []}],
#  'last_sale_date': '2004-12-14',
#  'total_value': 585739,
#  'owners': [{'id': 'Person.96d10c75-b090-4f82-939d-38d6b2a3fab2',
#    'name': 'Mr. Mike Allen Thomas',
#    'firstname': 'Mike',
#    'middlename': 'Allen',
#    'lastname': 'Thomas',
#    'alternate_names': [],
#    'age_range': '70-74',
#    'gender': 'Male',
#    'type': 'Person'}],
#  'associated_addresses': [],
#  'error': None,
#  'warnings': []}
